# %%
# !pip install ultralytics
# !pip install
# Out:
# ...
# ERROR: You must give at least one requirement to install (see "pip help install")

# %%
import os 
import random
from PIL import Image
from ultralytics import YOLO
from IPython.display import display

# %%
model = YOLO('yolov8n.pt')
results = model.train(data='data/data.yaml', epochs=10, imgsz=512)
# Out:
# New https://pypi.org/project/ultralytics/8.2.81 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.76 🚀 Python-3.11.5 torch-2.4.0 CPU (Apple M2)
# ...

# %%
model.val(data='data/data.yaml')
# Out:
# Ultralytics YOLOv8.2.76 🚀 Python-3.11.5 torch-2.4.0 CPU (Apple M2)
# Model summary (fused): 168 layers, 3,007,013 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /Users/andrewf1amex/Programming/Machine-learning/Bone-fracture-detection/data/valid/labels.cache... 348 images, 175 backgrounds, 0 corrupt: 100%|██████████| 348/348 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 22/22 [00:30<00:00,  1.40s/it]
#                    all        348        204      0.387      0.307      0.243     0.0886
#         elbow positive         28         29      0.202      0.172     0.0871     0.0259
#       fingers positive         41         48      0.294      0.188      0.161     0.0522
#       forearm fracture         37         43      0.427      0.442      0.408       0.17
#                humerus         31         36      0.674      0.444      0.476      0.183
# ...

# %%
images = os.listdir('data/test/images')
sample_images = random.sample(images, 5)
save_dir = '/opt/homebrew/runs/detect/bones'
os.makedirs(save_dir, exist_ok=True)

for image in sample_images: 
    image_path = os.path.join('data/test/images', image)
    results = model(image_path)
    
    for i, result in enumerate(results):
        result.plot(save=True, filename=os.path.join(save_dir, os.path.basename(image_path)))
        result_image_path = os.path.join(save_dir, os.path.basename(image_path))
        display(Image.open(result_image_path))
# Out:
# image 1/1 /Users/andrewf1amex/Programming/Machine-learning/Bone-fracture-detection/data/test/images/image1_2794_png.rf.6b3aeafbe8917839f42840a597349a32.jpg: 512x416 (no detections), 79.6ms
# Speed: 1.2ms preprocess, 79.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 416)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=406x512>
# image 1/1 /Users/andrewf1amex/Programming/Machine-learning/Bone-fracture-detection/data/test/images/image1_358_png.rf.ae461871b8aa93ee2b62c42d61ada754.jpg: 512x384 (no detections), 41.8ms
# Speed: 0.7ms preprocess, 41.8ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 384)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=354x512>
# image 1/1 /Users/andrewf1amex/Programming/Machine-learning/Bone-fracture-detection/data/test/images/image1_670_png.rf.da8ddaaa5ef3e99f8da51b6664740aa4.jpg: 512x416 (no detections), 51.9ms
# Speed: 0.8ms preprocess, 51.9ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 416)
# ...
